# %% [markdown]
# # Decision Tree Algorithm - insurance_charge_prediction
# # using Grid Search CV
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

"""
hyper parameters:
criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
splitter   {“best”, “random”}, default=”best”
max_features  int, float or {“sqrt”, “log2”}, default=None

"""
# parameter grid 
param_grid = { 
    "criterion":["squared_error","friedman_mse","absolute_error","poisson"],
    "splitter": ["best","random"],
    "max_features" : ["sqrt","log2"]
}
# model
model = DecisionTreeRegressor()
# model creation 
grid_model = GridSearchCV(model, param_grid, refit=True, verbose=3,n_jobs=-1)
grid_model.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
"""
criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
splitter   {“best”, “random”}, default=”best”
max_features  int, float or {“sqrt”, “log2”}, default=None
"""
# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor(criterion="absolute_error",splitter="best",random_state=0, max_features="sqrt")
# regressor.fit(x_train,y_train)
# Out:
# '\ncriterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”\nsplitter   {“best”, “random”}, default=”best”\nmax_features  int, float or {“sqrt”, “log2”}, default=None\n'

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_predict)
print(f" THE ACCURACY OF THE MODEL : {r_score}")    # THE ACCURACY OF THE MODEL : 0.7538062098354589   --- using criterion="absolute_error",splitter="random"
# Out:
#  THE ACCURACY OF THE MODEL : 0.7885524275111394

# %% [markdown]
# ## Grid Search CV results

# %%
grid_result = grid_model.cv_results_
grid_result
# Out:
# {'mean_fit_time': array([0.01874223, 0.01434193, 0.02010288, 0.01275072, 0.01477327,
#         0.0137867 , 0.01460142, 0.01516838, 0.04044166, 0.02992067,
#         0.03972483, 0.04482899, 0.03438993, 0.02205682, 0.02179179,
#         0.02221384]),
#  'std_fit_time': array([0.00146159, 0.00161645, 0.00407756, 0.00124583, 0.00062465,
#         0.00238664, 0.00100545, 0.00478682, 0.00338054, 0.00187969,
#         0.00391617, 0.01792501, 0.01945843, 0.00349606, 0.00128593,
#         0.0052499 ]),
#  'mean_score_time': array([0.01141434, 0.01224799, 0.01059256, 0.00848799, 0.00831246,
#         0.0087966 , 0.00865192, 0.00783911, 0.00793343, 0.00824804,
#         0.00805812, 0.0111516 , 0.01575646, 0.01186495, 0.0113513 ,
#         0.01125369]),
#  'std_score_time': array([0.00348599, 0.0026029 , 0.00303932, 0.00058068, 0.00071212,
#         0.00122505, 0.00051487, 0.00020867, 0.00044352, 0.00050596,
#         0.00029121, 0.00388063, 0.00245862, 0.0015272 , 0.00058215,
#         0.00141601]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'friedman_mse', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'poisson', 'poisson', 'poisson', 'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_max_features': masked_array(data=['sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random', 'best', 'random',
#                     'best', 'random', 'best', 'random'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'sqrt',
#    'splitter': 'random'},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'absolute_error',
#    'max_features': 'log2',
#    'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'},
#   {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}],
#  'split0_test_score': array([0.63104924, 0.66415927, 0.66904031, 0.69264905, 0.71275689,
#         0.60837929, 0.70001084, 0.67912051, 0.70811925, 0.5900899 ,
#         0.70212214, 0.71088928, 0.73118361, 0.53704902, 0.68364164,
#         0.68408933]),
#  'split1_test_score': array([0.58299569, 0.52848924, 0.6013574 , 0.51675788, 0.6219934 ,
#         0.61727647, 0.64221877, 0.59256156, 0.58480256, 0.68720197,
#         0.59205418, 0.57592318, 0.47570586, 0.57201179, 0.63918313,
#         0.52059248]),
#  'split2_test_score': array([0.66556639, 0.73006671, 0.66394161, 0.68060077, 0.74007223,
#         0.61908076, 0.76743529, 0.78483292, 0.48823126, 0.6824868 ,
#         0.67253909, 0.67692257, 0.72951121, 0.67370494, 0.70870523,
#         0.68084549]),
#  'split3_test_score': array([0.6966535 , 0.68860666, 0.69647868, 0.73597717, 0.78194125,
#         0.7187522 , 0.70123473, 0.68076757, 0.73454544, 0.64385768,
#         0.71536509, 0.74550868, 0.62985056, 0.69888417, 0.60068933,
#         0.66511657]),
#  'split4_test_score': array([0.57970871, 0.7378814 , 0.39204688, 0.60230878, 0.74071239,
#         0.65223974, 0.72236462, 0.64191375, 0.57890293, 0.67816913,
#         0.61678464, 0.55409781, 0.75574209, 0.66367878, 0.63157874,
#         0.70028121]),
#  'mean_test_score': array([0.63119471, 0.66984066, 0.60457298, 0.64565873, 0.71949523,
#         0.64314569, 0.70665285, 0.67583926, 0.61892029, 0.6563611 ,
#         0.65977303, 0.65266831, 0.66439867, 0.62906574, 0.65275961,
#         0.65018502]),
#  'std_test_score': array([0.04569517, 0.07565895, 0.11072941, 0.0775643 , 0.05352588,
#         0.04063517, 0.04041432, 0.0632468 , 0.09074212, 0.03648975,
#         0.04791814, 0.07510425, 0.10377094, 0.06290877, 0.03854316,
#         0.06575161]),
#  'rank_test_score': array([13,  4, 16, 11,  1, 12,  2,  3, 15,  7,  6,  9,  5, 14,  8, 10],
#        dtype=int32)}

# %%
table = pd.DataFrame.from_dict(grid_result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018742      0.001462         0.011414        0.003486
# 1        0.014342      0.001616         0.012248        0.002603
# 2        0.020103      0.004078         0.010593        0.003039
# 3        0.012751      0.001246         0.008488        0.000581
# 4        0.014773      0.000625         0.008312        0.000712
# 5        0.013787      0.002387         0.008797        0.001225
# 6        0.014601      0.001005         0.008652        0.000515
# 7        0.015168      0.004787         0.007839        0.000209
# 8        0.040442      0.003381         0.007933        0.000444
# 9        0.029921      0.001880         0.008248        0.000506
# 10       0.039725      0.003916         0.008058        0.000291
# 11       0.044829      0.017925         0.011152        0.003881
# 12       0.034390      0.019458         0.015756        0.002459
# 13       0.022057      0.003496         0.011865        0.001527
# 14       0.021792      0.001286         0.011351        0.000582
# 15       0.022214      0.005250         0.011254        0.001416
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.631049
# 1   {'criterion': 'squared_error', 'max_features':...           0.664159
# 2   {'criterion': 'squared_error', 'max_features':...           0.669040
# 3   {'criterion': 'squared_error', 'max_features':...           0.692649
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.712757
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.608379
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.700011
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.679121
# 8   {'criterion': 'absolute_error', 'max_features'...           0.708119
# 9   {'criterion': 'absolute_error', 'max_features'...           0.590090
# 10  {'criterion': 'absolute_error', 'max_features'...           0.702122
# 11  {'criterion': 'absolute_error', 'max_features'...           0.710889
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.731184
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.537049
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.683642
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.684089
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.582996           0.665566           0.696654
# 1            0.528489           0.730067           0.688607
# 2            0.601357           0.663942           0.696479
# 3            0.516758           0.680601           0.735977
# 4            0.621993           0.740072           0.781941
# 5            0.617276           0.619081           0.718752
# 6            0.642219           0.767435           0.701235
# 7            0.592562           0.784833           0.680768
# 8            0.584803           0.488231           0.734545
# 9            0.687202           0.682487           0.643858
# 10           0.592054           0.672539           0.715365
# 11           0.575923           0.676923           0.745509
# 12           0.475706           0.729511           0.629851
# 13           0.572012           0.673705           0.698884
# 14           0.639183           0.708705           0.600689
# 15           0.520592           0.680845           0.665117
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.579709         0.631195        0.045695               13
# 1            0.737881         0.669841        0.075659                4
# 2            0.392047         0.604573        0.110729               16
# 3            0.602309         0.645659        0.077564               11
# 4            0.740712         0.719495        0.053526                1
# 5            0.652240         0.643146        0.040635               12
# 6            0.722365         0.706653        0.040414                2
# 7            0.641914         0.675839        0.063247                3
# 8            0.578903         0.618920        0.090742               15
# 9            0.678169         0.656361        0.036490                7
# 10           0.616785         0.659773        0.047918                6
# 11           0.554098         0.652668        0.075104                9
# 12           0.755742         0.664399        0.103771                5
# 13           0.663679         0.629066        0.062909               14
# 14           0.631579         0.652760        0.038543                8
# 15           0.700281         0.650185        0.065752               10

# %%
grid_model.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
grid_model.best_estimator_
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_features='sqrt')

# %% [markdown]
# ## Model Accuracy

# %%
"""
parameter                                                                       Accuracy
{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'} -     0.7194952320691046   (best score using grid CV)
"""
grid_model.best_score_
# Out:
# np.float64(0.7194952320691046)

# %% [markdown]
# ## save the model

# %%
# import pickle 
# pickle.dump(regressor, open(" ","wb"))

# %%
grid_model.predict([[ 52, 30.200, 1, 1, 0 ]])
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([9724.53])
