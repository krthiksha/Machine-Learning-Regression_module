# %% [markdown]
# # Support Vector Machine Algorithm -  insurance_charge_prediction
# # Using Grid Search CV
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## split train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %% [markdown]
# ## model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
""" "kernel":["linear", "poly", "rbf", "sigmoid"],   """

# parameter grid for SVR model 
param_grid = {
                "kernel":["linear"],
                "C":[10,100,500,1000,2000,3000],
                "gamma": ["scale", "auto"]
             }
# model 
# model = SVR()
# model creation using grid search CV 
""" 
refit True - to select the best model 
"""
grid_model= GridSearchCV(SVR(),param_grid, refit=True, verbose=3, n_jobs=-1)
# grid_model.fit(independent, dependent)   # passing the input and output data

grid_model.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 500, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'], 'kernel': ['linear']},
#              verbose=3)

# %% [markdown]
# ## Grid Search CV results

# %%
# result viewed in dictionary format
gridcv_result = grid_model.cv_results_
gridcv_result
# Out:
# {'mean_fit_time': array([0.34772229, 0.1795857 , 0.50296245, 0.33627744, 0.79130278,
#         0.76552186, 1.2898294 , 1.23538642, 2.22269044, 2.18236637,
#         3.95177469, 3.56553669]),
#  'std_fit_time': array([0.10748336, 0.0516661 , 0.0879525 , 0.06086922, 0.03664506,
#         0.020791  , 0.1406598 , 0.16006287, 0.37552414, 0.34245296,
#         1.31648427, 1.18938406]),
#  'mean_score_time': array([0.04892688, 0.02238727, 0.02562218, 0.02313538, 0.01853929,
#         0.01892686, 0.01870227, 0.01897879, 0.02409325, 0.01871543,
#         0.02145123, 0.02023387]),
#  'std_score_time': array([0.01933014, 0.00326802, 0.00773425, 0.00497011, 0.00037934,
#         0.00070072, 0.00042532, 0.00091818, 0.00916365, 0.0006074 ,
#         0.00396384, 0.00361552]),
#  'param_C': masked_array(data=[10, 10, 100, 100, 500, 500, 1000, 1000, 2000, 2000,
#                     3000, 3000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value=999999),
#  'param_gamma': masked_array(data=['scale', 'auto', 'scale', 'auto', 'scale', 'auto',
#                     'scale', 'auto', 'scale', 'auto', 'scale', 'auto'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'linear', 'linear', 'linear', 'linear',
#                     'linear', 'linear', 'linear', 'linear', 'linear',
#                     'linear', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 500, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}],
#  'split0_test_score': array([-0.10023134, -0.10023134,  0.4869666 ,  0.4869666 ,  0.57913397,
#          0.57913397,  0.59079677,  0.59079677,  0.59654022,  0.59654022,
#          0.59765936,  0.59765936]),
#  'split1_test_score': array([0.06647746, 0.06647746, 0.55177971, 0.55177971, 0.62515466,
#         0.62515466, 0.66680502, 0.66680502, 0.68162423, 0.68162423,
#         0.63543382, 0.63543382]),
#  'split2_test_score': array([-0.03978296, -0.03978296,  0.52733745,  0.52733745,  0.61508793,
#          0.61508793,  0.63681693,  0.63681693,  0.7046342 ,  0.7046342 ,
#          0.69372681,  0.69372681]),
#  'split3_test_score': array([-0.07494637, -0.07494637,  0.4896345 ,  0.4896345 ,  0.5807952 ,
#          0.5807952 ,  0.6076905 ,  0.6076905 ,  0.69676651,  0.69676651,
#          0.68986189,  0.68986189]),
#  'split4_test_score': array([-0.09012956, -0.09012956,  0.4600143 ,  0.4600143 ,  0.54785271,
#          0.54785271,  0.57164714,  0.57164714,  0.65611938,  0.65611938,
#          0.60759378,  0.60759378]),
#  'mean_test_score': array([-0.04772255, -0.04772255,  0.50314651,  0.50314651,  0.58960489,
#          0.58960489,  0.61475127,  0.61475127,  0.66713691,  0.66713691,
#          0.64485513,  0.64485513]),
#  'std_test_score': array([0.06066522, 0.06066522, 0.03241956, 0.03241956, 0.02772604,
#         0.02772604, 0.03369903, 0.03369903, 0.03898492, 0.03898492,
#         0.04029556, 0.04029556]),
#  'rank_test_score': array([11, 11,  9,  9,  7,  7,  5,  5,  1,  1,  3,  3], dtype=int32)}

# %%
# result viewed in tabular format
gridcv_result_table = pd.DataFrame.from_dict(gridcv_result)
gridcv_result_table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.347722      0.107483         0.048927        0.019330       10
# 1        0.179586      0.051666         0.022387        0.003268       10
# 2        0.502962      0.087952         0.025622        0.007734      100
# 3        0.336277      0.060869         0.023135        0.004970      100
# 4        0.791303      0.036645         0.018539        0.000379      500
# 5        0.765522      0.020791         0.018927        0.000701      500
# 6        1.289829      0.140660         0.018702        0.000425     1000
# 7        1.235386      0.160063         0.018979        0.000918     1000
# 8        2.222690      0.375524         0.024093        0.009164     2000
# 9        2.182366      0.342453         0.018715        0.000607     2000
# 10       3.951775      1.316484         0.021451        0.003964     3000
# 11       3.565537      1.189384         0.020234        0.003616     3000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1         auto       linear
# 2        scale       linear
# 3         auto       linear
# 4        scale       linear
# 5         auto       linear
# 6        scale       linear
# 7         auto       linear
# 8        scale       linear
# 9         auto       linear
# 10       scale       linear
# 11        auto       linear
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.100231
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.100231
# 2    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.486967
# 3     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.486967
# 4    {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.579134
# 5     {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.579134
# 6   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.590797
# 7    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.590797
# 8   {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.596540
# 9    {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.596540
# 10  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.597659
# 11   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.597659
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.066477          -0.039783          -0.074946
# 1            0.066477          -0.039783          -0.074946
# 2            0.551780           0.527337           0.489634
# 3            0.551780           0.527337           0.489634
# 4            0.625155           0.615088           0.580795
# 5            0.625155           0.615088           0.580795
# 6            0.666805           0.636817           0.607690
# 7            0.666805           0.636817           0.607690
# 8            0.681624           0.704634           0.696767
# 9            0.681624           0.704634           0.696767
# 10           0.635434           0.693727           0.689862
# 11           0.635434           0.693727           0.689862
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.090130        -0.047723        0.060665               11
# 1           -0.090130        -0.047723        0.060665               11
# 2            0.460014         0.503147        0.032420                9
# 3            0.460014         0.503147        0.032420                9
# 4            0.547853         0.589605        0.027726                7
# 5            0.547853         0.589605        0.027726                7
# 6            0.571647         0.614751        0.033699                5
# 7            0.571647         0.614751        0.033699                5
# 8            0.656119         0.667137        0.038985                1
# 9            0.656119         0.667137        0.038985                1
# 10           0.607594         0.644855        0.040296                3
# 11           0.607594         0.644855        0.040296                3

# %%
# best parameters -(syntax: model.best_params_ )
grid_model.best_params_
# Out:
# {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}

# %%
#  best model 
grid_model.best_estimator_
# Out:
# SVR(C=2000, kernel='linear')

# %% [markdown]
# ## Model Accuracy

# %%
""" 
MODEL ACCURACY Analysis:-
---- by passing 'independent and dependent' to the grid_model
parameter                                                      Accuracy 
{'C': 1000, 'gamma': 'scale', 'kernel': 'linear'} -      0.6937782148821102     ( comparatively best model )
{'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'} -          0.015505864908097754
{'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'} -        -0.10475314338568928

--- by passing 'train test split' to the grid_model 
parameter                                                      Accuracy 
{'C': 2000, 'gamma': 'scale', 'kernel': 'linear'} -      0.667136907660572     ( comparatively best model )
{'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'} -          -0.021844607356429256
{'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'} -        -0.10306385877865512
"""

# best accuracy score 
grid_model.best_score_
# Out:
# np.float64(0.667136907660572)

# %% [markdown]
# ## save the model

# %%
# import pickle 
# pickle.dump(regressor, open(" ","wb"))

# %%
future_prediction = grid_model.predict([[ 52, 30.200, 1, 1, 0 ]])
future_prediction
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([10220.32601213])
