# %% [markdown]
# # Random Forest Regressor Algorithm -  insurance_charge_prediction
# # using Grid Search CV
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## split train test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %% [markdown]
# ## model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# parameter grid
param_grid = { 
    "criterion":["squared_error","friedman_mse","absolute_error","poisson"],
     "max_features" : ["sqrt","log2",None],
    "n_estimators": [50,100,150,200]
}
# model 
model = RandomForestRegressor()
# model creation 
grid_model = GridSearchCV(model, param_grid, refit = True, verbose=3, n_jobs=-1)
grid_model.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# E:\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100, 150, 200]},
#              verbose=3)

# %%
# from sklearn.ensemble import RandomForestRegressor
# # criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”mse"
# regressor = RandomForestRegressor(n_estimators=100,random_state=0, criterion="poisson")
# regressor.fit(x_train, y_train)

# %% [markdown]
# ## Grid Search CV results

# %%
grid_result = grid_model.cv_results_
grid_result
# Out:
# {'mean_fit_time': array([0.3550777 , 0.68896823, 1.01514769, 1.36752033, 0.35080323,
#         0.70046935, 0.98279538, 1.31504507, 0.43130498, 0.8189537 ,
#         1.24246373, 1.66339698, 0.37734785, 0.66140189, 1.02577538,
#         1.36684761, 0.33622556, 0.68671455, 0.99075732, 1.34182587,
#         0.40606961, 0.85326791, 1.20033722, 1.68414469, 0.97192578,
#         1.88587937, 2.79956374, 5.5122838 , 3.04517426, 9.95299025,
#         5.59610391, 5.94390464, 2.36583443, 4.06112595, 5.22692947,
#         5.91746459, 0.37698655, 0.74581108, 1.13314605, 1.5336947 ,
#         0.39949937, 0.75592537, 1.20503545, 1.58166428, 0.51741152,
#         1.00037756, 1.54232383, 1.88729672]),
#  'std_fit_time': array([0.02549124, 0.03040152, 0.04082093, 0.0438171 , 0.03454048,
#         0.04518128, 0.02364371, 0.02296889, 0.01978901, 0.02393073,
#         0.03490939, 0.03569745, 0.04514306, 0.00849032, 0.03661812,
#         0.06003984, 0.00959361, 0.01417591, 0.02190969, 0.0158798 ,
#         0.01860857, 0.04407071, 0.02686321, 0.04146161, 0.05087344,
#         0.05429962, 0.06979436, 0.74179595, 1.51334482, 1.10021775,
#         1.9633996 , 0.9730536 , 0.6272506 , 0.10247467, 0.43335194,
#         0.12225479, 0.01297594, 0.00419036, 0.02974062, 0.02330817,
#         0.03464704, 0.05240738, 0.08974567, 0.03606098, 0.0302911 ,
#         0.02356346, 0.05841924, 0.03140696]),
#  'mean_score_time': array([0.02699561, 0.04494667, 0.06355886, 0.09961071, 0.02690978,
#         0.05385447, 0.06791906, 0.08211365, 0.02795234, 0.04705267,
#         0.06362162, 0.0882494 , 0.02915716, 0.05474529, 0.07392716,
#         0.08962994, 0.03430305, 0.04492178, 0.06317306, 0.08574624,
#         0.81592489, 0.81763956, 0.81718747, 0.81318582, 0.81573305,
#         0.81587444, 0.81707479, 0.7984868 , 0.8023712 , 0.80232373,
#         0.8022401 , 0.81505387, 0.8183012 , 0.81712389, 0.81632498,
#         0.812251  , 0.81576299, 0.81775132, 0.81655832, 0.81041162,
#         0.80787812, 0.80849397, 0.80856993]),
#  'std_test_score': array([0.02983686, 0.0270768 , 0.02795403, 0.02728647, 0.02999743,
#         0.02616385, 0.02843379, 0.02701424, 0.02670786, 0.0266183 ,
#         0.02590593, 0.02538408, 0.02870597, 0.02871805, 0.02837946,
#         0.02762462, 0.02929949, 0.02978209, 0.02769173, 0.02737991,
#         0.02514277, 0.02680399, 0.02598528, 0.02653087, 0.02942633,
#         0.02870367, 0.02654815, 0.02562653, 0.02512887, 0.02774563,
#         0.02556837, 0.02697703, 0.0303401 , 0.03010382, 0.02993483,
#         0.03074422, 0.02876863, 0.0255801 , 0.02787953, 0.02743125,
#         0.02959971, 0.02725081, 0.02919187, 0.02859232, 0.02551571,
#         0.02760132, 0.02576918, 0.0255955 ]),
#  'rank_test_score': array([28, 18, 24,  7, 30, 13, 15,  4, 44, 37, 38, 41, 29,  6, 26, 11, 32,
#         12,  5, 14, 39, 43, 42, 34, 25, 19,  3,  8, 27, 22, 20, 10, 48, 45,
#         46, 47, 23,  1,  9, 17, 31, 21,  2, 16, 33, 40, 36, 35],
#        dtype=int32)}

# %%
table = pd.DataFrame.from_dict(grid_result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.355078      0.025491         0.026996        0.000858
# 1        0.688968      0.030402         0.044947        0.000856
# 2        1.015148      0.040821         0.063559        0.001484
# 3        1.367520      0.043817         0.099611        0.019540
# 4        0.350803      0.034540         0.026910        0.001024
# 5        0.700469      0.045181         0.053854        0.008962
# 6        0.982795      0.023644         0.067919        0.005634
# 7        1.315045      0.022969         0.082114        0.002004
# 8        0.431305      0.019789         0.027952        0.002893
# 9        0.818954      0.023931         0.047053        0.004516
# 10       1.242464      0.034909         0.063622        0.001239
# 11       1.663397      0.035697         0.088249        0.013097
# 12       0.377348      0.045143         0.029157        0.002521
# 13       0.661402      0.008490         0.054745        0.016853
# 14       1.025775      0.036618         0.073927        0.017389
# 15       1.366848      0.060040         0.089630        0.009431
# 16       0.336226      0.009594         0.034303        0.014108
# 17       0.686715      0.014176         0.044922        0.001140
# 18       0.990757      0.021910         0.063173        0.001166
# 19       1.341826      0.015880         0.085746        0.003074
# 20       0.406070      0.018609         0.027746        0.001937
# 21       0.853268      0.044071         0.045762        0.001499
# 22       1.200337      0.026863         0.066142        0.005916
# 23       1.684145      0.041462         0.087030        0.006122
# 24       0.971926      0.050873         0.029405        0.002539
# 25       1.885879      0.054300         0.049624        0.004422
# 26       2.799564      0.069794         0.068965        0.006945
# 27       5.512284      0.741796         0.209234        0.151538
# 28       3.045174      1.513345         0.181415        0.179461
# 29       9.952990      1.100218         0.207764        0.094070
# 30       5.596104      1.963400         0.158768        0.095429
# 31       5.943905      0.973054         0.181223        0.108722
# 32       2.365834      0.627251         0.044295        0.011940
# 33       4.061126      0.102475         0.074126        0.008177
# 34       5.226929      0.433352         0.081248        0.017133
# 35       5.917465      0.122255         0.099394        0.012646
# 36       0.376987      0.012976         0.027285        0.000674
# 37       0.745811      0.004190         0.048069        0.000520
# 38       1.133146      0.029741         0.067816        0.001990
# 39       1.533695      0.023308         0.089559        0.002951
# 40       0.399499      0.034647         0.029219        0.002105
# 41       0.755925      0.052407         0.054135        0.009977
# 42       1.205035      0.089746         0.066419        0.001691
# 43       1.581664      0.036061         0.104861        0.014388
# 44       0.517412      0.030291         0.029648        0.002012
# 45       1.000378      0.023563         0.048497        0.002384
# 46       1.542324      0.058419         0.080038        0.013064
# 47       1.887297      0.031407         0.085549        0.002654
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  50
# 1    squared_error               sqrt                 100
# 2    squared_error               sqrt                 150
# 3    squared_error               sqrt                 200
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6    squared_error               log2                 150
# 7    squared_error               log2                 200
# 8    squared_error               None                  50
# 9    squared_error               None                 100
# 10   squared_error               None                 150
# 11   squared_error               None                 200
# 12    friedman_mse               sqrt                  50
# 13    friedman_mse               sqrt                 100
# 14    friedman_mse               sqrt                 150
# 15    friedman_mse               sqrt                 200
# 16    friedman_mse               log2                  50
# 17    friedman_mse               log2                 100
# 18    friedman_mse               log2                 150
# 19    friedman_mse               log2                 200
# 20    friedman_mse               None                  50
# 21    friedman_mse               None                 100
# 22    friedman_mse               None                 150
# 23    friedman_mse               None                 200
# 24  absolute_error               sqrt                  50
# 25  absolute_error               sqrt                 100
# 26  absolute_error               sqrt                 150
# 27  absolute_error               sqrt                 200
# 28  absolute_error               log2                  50
# 29  absolute_error               log2                 100
# 30  absolute_error               log2                 150
# 31  absolute_error               log2                 200
# 32  absolute_error               None                  50
# 33  absolute_error               None                 100
# 34  absolute_error               None                 150
# 35  absolute_error               None                 200
# 36         poisson               sqrt                  50
# 37         poisson               sqrt                 100
# 38         poisson               sqrt                 150
# 39         poisson               sqrt                 200
# 40         poisson               log2                  50
# 41         poisson               log2                 100
# 42         poisson               log2                 150
# 43         poisson               log2                 200
# 44         poisson               None                  50
# 45         poisson               None                 100
# 46         poisson               None                 150
# 47         poisson               None                 200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.847968
# 1   {'criterion': 'squared_error', 'max_features':...           0.845006
# 2   {'criterion': 'squared_error', 'max_features':...           0.847729
# 3   {'criterion': 'squared_error', 'max_features':...           0.844472
# 4   {'criterion': 'squared_error', 'max_features':...           0.845137
# 5   {'criterion': 'squared_error', 'max_features':...           0.842532
# 6   {'criterion': 'squared_error', 'max_features':...           0.846597
# 7   {'criterion': 'squared_error', 'max_features':...           0.848056
# 8   {'criterion': 'squared_error', 'max_features':...           0.842800
# 9   {'criterion': 'squared_error', 'max_features':...           0.847376
# 10  {'criterion': 'squared_error', 'max_features':...           0.847141
# 11  {'criterion': 'squared_error', 'max_features':...           0.846520
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.844800
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.848810
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.846783
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.848576
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.842662
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.847506
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.849111
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.847821
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.848015
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.846036
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.847527
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.848577
# 24  {'criterion': 'absolute_error', 'max_features'...           0.849363
# 25  {'criterion': 'absolute_error', 'max_features'...           0.851832
# 26  {'criterion': 'absolute_error', 'max_features'...           0.852390
# 27  {'criterion': 'absolute_error', 'max_features'...           0.849367
# 28  {'criterion': 'absolute_error', 'max_features'...           0.848302
# 29  {'criterion': 'absolute_error', 'max_features'...           0.849468
# 30  {'criterion': 'absolute_error', 'max_features'...           0.846540
# 31  {'criterion': 'absolute_error', 'max_features'...           0.848823
# 32  {'criterion': 'absolute_error', 'max_features'...           0.844302
# 33  {'criterion': 'absolute_error', 'max_features'...           0.846616
# 34  {'criterion': 'absolute_error', 'max_features'...           0.845796
# 35  {'criterion': 'absolute_error', 'max_features'...           0.848869
# 36  {'criterion': 'poisson', 'max_features': 'sqrt...           0.849646
# 37  {'criterion': 'poisson', 'max_features': 'sqrt...           0.844494
# 38  {'criterion': 'poisson', 'max_features': 'sqrt...           0.848209
# 39  {'criterion': 'poisson', 'max_features': 'sqrt...           0.846466
# 40  {'criterion': 'poisson', 'max_features': 'log2...           0.844464
# 41  {'criterion': 'poisson', 'max_features': 'log2...           0.847414
# 42  {'criterion': 'poisson', 'max_features': 'log2...           0.849795
# 43  {'criterion': 'poisson', 'max_features': 'log2...           0.849328
# 44  {'criterion': 'poisson', 'max_features': None,...           0.843672
# 45  {'criterion': 'poisson', 'max_features': None,...           0.847952
# 46  {'criterion': 'poisson', 'max_features': None,...           0.845128
# 47  {'criterion': 'poisson', 'max_features': None,...           0.843448
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.824836           0.796556           0.832685
# 1            0.825579           0.804953           0.836630
# 2            0.822479           0.798910           0.835909
# 3            0.824911           0.802631           0.842336
# 4            0.823152           0.801530           0.832589
# 5            0.824609           0.808011           0.838617
# 6            0.828475           0.801815           0.838126
# 7            0.825743           0.804226           0.837654
# 8            0.815398           0.791532           0.817439
# 9            0.824383           0.793440           0.806903
# 10           0.820510           0.793755           0.809690
# 11           0.817331           0.793552           0.809769
# 12           0.824001           0.799920           0.832238
# 13           0.824757           0.798496           0.843035
# 14           0.823855           0.800976           0.832657
# 15           0.823138           0.801275           0.839687
# 16           0.821392           0.798924           0.832468
# 17           0.823107           0.800878           0.845001
# 18           0.827472           0.804086           0.836013
# 19           0.825044           0.802256           0.837368
# 20           0.815571           0.790446           0.811743
# 21           0.818699           0.790199           0.812914
# 22           0.816845           0.793146           0.809605
# 23           0.817508           0.794295           0.815192
# 24           0.826179           0.806926           0.827271
# 25           0.821540           0.806845           0.832794
# 26           0.822284           0.807251           0.832854
# 27           0.823432           0.808301           0.831520
# 28           0.815887           0.804126           0.825464
# 29           0.819644           0.807788           0.833985
# 30           0.823137           0.802870           0.833378
# 31           0.823713           0.807959           0.834652
# 32           0.815122           0.773211           0.801076
# 33           0.813551           0.787969           0.808315
# 34           0.816312           0.783420           0.808485
# 35           0.812124           0.784432           0.809231
# 36           0.820951           0.793991           0.839063
# 37           0.825919           0.811699           0.837208
# 38           0.827458           0.802572           0.837161
# 39           0.827230           0.801740           0.836050
# 40           0.825350           0.789708           0.835536
# 41           0.823907           0.800928           0.835790
# 42           0.827437           0.803808           0.839635
# 43           0.825314           0.805875           0.835395
# 44           0.825408           0.792285           0.819238
# 45           0.819835           0.792333           0.813646
# 46           0.821529           0.795744           0.811991
# 47           0.825030           0.795297           0.810602
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.763699         0.813149        0.029837               28
# 1            0.769251         0.816284        0.027077               18
# 2            0.769349         0.814875        0.027954               24
# 3            0.771643         0.817199        0.027286                7
# 4            0.759616         0.812405        0.029997               30
# 5            0.770470         0.816848        0.026164               13
# 6            0.768437         0.816690        0.028434               15
# 7            0.772060         0.817548        0.027014                4
# 8            0.763763         0.806186        0.026708               44
# 9            0.769130         0.808246        0.026618               37
# 10           0.769771         0.808174        0.025906               38
# 11           0.770045         0.807443        0.025384               41
# 12           0.763535         0.812899        0.028706               29
# 13           0.771920         0.817403        0.028718                6
# 14           0.765653         0.813985        0.028379               26
# 15           0.772068         0.816949        0.027625               11
# 16           0.760253         0.811140        0.029299               32
# 17           0.767775         0.816854        0.029782               12
# 18           0.770460         0.817429        0.027692                5
# 19           0.771155         0.816729        0.027380               14
# 20           0.773646         0.807884        0.025143               39
# 21           0.766821         0.806934        0.026804               43
# 22           0.769075         0.807240        0.025985               42
# 23           0.768673         0.808849        0.026531               34
# 24           0.761989         0.814345        0.029426               25
# 25           0.766614         0.815925        0.028704               19
# 26           0.773419         0.817640        0.026548                3
# 27           0.773317         0.817187        0.025627                8
# 28           0.772149         0.813186        0.025129               27
# 29           0.767780         0.815733        0.027746               22
# 30           0.773447         0.815874        0.025568               20
# 31           0.770227         0.817075        0.026977               10
# 32           0.758722         0.798487        0.030340               48
# 33           0.755405         0.802371        0.030104               45
# 34           0.757606         0.802324        0.029935               46
# 35           0.756545         0.802240        0.030744               47
# 36           0.771618         0.815054        0.028769               23
# 37           0.772187         0.818301        0.025580                1
# 38           0.770219         0.817124        0.027880                9
# 39           0.770139         0.816325        0.027431               17
# 40           0.766196         0.812251        0.029600               31
# 41           0.770776         0.815763        0.027251               21
# 42           0.768083         0.817751        0.029192                2
# 43           0.766878         0.816558        0.028592               16
# 44           0.771455         0.810412        0.025516               33
# 45           0.765625         0.807878        0.027601               40
# 46           0.768078         0.808494        0.025769               36
# 47           0.768471         0.808570        0.025596               35

# %%
grid_model.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
grid_model.best_estimator_
# Out:
# RandomForestRegressor(criterion='poisson', max_features='sqrt')

# %% [markdown]
# ## Model Accuracy

# %%
"""
parameter                                                                       Accuracy
{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100} -     0.8183011956899856   (best score using grid CV)
"""

grid_model.best_score_
# Out:
# np.float64(0.8183011956899856)

# %% [markdown]
# ## save the model

# %%
# import pickle 
# pickle.dump(regressor, open("insurance_charge_finalModel_RF_regressor.sav","wb"))

# %% [markdown]
# ## predict the model

# %%
# insurance_charge_predict = pickle.load(open("insurance_charge_finalModel_RF_regressor.sav","rb"))
grid_model.predict([[ 52, 30.200, 1, 1, 0 ]])
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([10663.4306254])
