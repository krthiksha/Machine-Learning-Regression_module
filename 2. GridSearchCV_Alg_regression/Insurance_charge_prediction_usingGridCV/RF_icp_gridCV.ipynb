# %% [markdown]
# # Random Forest Regressor Algorithm -  insurance_charge_prediction
# # using Grid Search CV
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## split train test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %% [markdown]
# ## model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# parameter grid
param_grid = { 
    "criterion":["squared_error","friedman_mse","absolute_error","poisson"],
     "max_features" : ["sqrt","log2",None],
    "n_estimators": [50,100,150,200]
}
# model 
model = RandomForestRegressor()
# model creation 
grid_model = GridSearchCV(model, param_grid, refit = True, verbose=3, n_jobs=-1)
grid_model.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# E:\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [50, 100, 150, 200]},
#              verbose=3)

# %%
# from sklearn.ensemble import RandomForestRegressor
# # criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”mse"
# regressor = RandomForestRegressor(n_estimators=100,random_state=0, criterion="poisson")
# regressor.fit(x_train, y_train)

# %% [markdown]
# ## Grid Search CV results

# %%
grid_result = grid_model.cv_results_
grid_result
# Out:
# {'mean_fit_time': array([0.34665298, 0.67317781, 1.00562296, 1.51675525, 0.35033755,
#         0.70579782, 1.06828327, 1.48922315, 0.49746084, 1.10324569,
#         1.32968407, 1.65931902, 0.35039568, 0.65983596, 0.99613705,
#         1.38389702, 0.34367723, 0.65284095, 0.9921731 , 1.32259908,
#         0.42802429, 0.91673484, 1.27283382, 1.64721789, 0.80031142,
#         1.5713964 , 2.34262638, 3.07870002, 0.77703719, 1.56864862,
#         2.3369103 , 3.14787006, 1.25231524, 2.58910685, 3.78921642,
#         6.17345634, 0.46974235, 0.83569865, 1.36500983, 1.71698103,
#         0.57010436, 1.14851713, 1.61079116, 2.27074075, 0.75755882,
#         1.54530854, 1.56596408, 2.09074531]),
#  'std_fit_time': array([0.02119323, 0.02629055, 0.0239415 , 0.18558732, 0.02538866,
#         0.01783486, 0.13602608, 0.13768544, 0.03756469, 0.09473788,
#         0.02856457, 0.05899531, 0.02025494, 0.03143744, 0.02011497,
#         0.04352697, 0.02465072, 0.01554874, 0.02831716, 0.03250893,
#         0.04173739, 0.07176977, 0.0372476 , 0.02506403, 0.0386605 ,
#         0.03136189, 0.0411284 , 0.02982695, 0.01253775, 0.06455429,
#         0.06527996, 0.03818152, 0.01988493, 0.02853777, 0.04448564,
#         0.4970809 , 0.06298659, 0.02346613, 0.148411  , 0.14048262,
#         0.07950268, 0.19352944, 0.17233072, 0.38215612, 0.2403706 ,
#         0.30031708, 0.12942651, 0.08654013]),
#  'mean_score_time': array([0.02899618, 0.04852657, 0.06789522, 0.10658054, 0.02813897,
#         0.055229  , 0.06914477, 0.09071388, 0.03654408, 0.06040096,
#         0.07127013, 0.0836978 , 0.0272244 , 0.04523964, 0.07048965,
#         0.08670979, 0.0265347 , 0.05096827, 0.06440587, 0.08826208,
#         0.8152333 , 0.81495046, 0.79787093, 0.80075161, 0.80001699,
#         0.80211948, 0.81522883, 0.81606367, 0.81736563, 0.81588867,
#         0.81615334, 0.81162506, 0.8145975 , 0.81629485, 0.80782678,
#         0.80835717, 0.80706675, 0.81017882]),
#  'std_test_score': array([0.02463256, 0.02684565, 0.02658015, 0.02609562, 0.02759574,
#         0.02800949, 0.02587692, 0.02656145, 0.02526843, 0.02399831,
#         0.02582136, 0.02469728, 0.02898966, 0.026158  , 0.02734446,
#         0.02629065, 0.02786673, 0.02958668, 0.02717501, 0.02832972,
#         0.02395017, 0.02739294, 0.02756006, 0.02723429, 0.02629287,
#         0.02856957, 0.02669061, 0.02690628, 0.0267515 , 0.0265494 ,
#         0.02737495, 0.02677183, 0.02919008, 0.03046591, 0.02928233,
#         0.03028998, 0.03190639, 0.02672581, 0.02830891, 0.02528128,
#         0.02625449, 0.02514401, 0.0273833 , 0.02679369, 0.02660524,
#         0.02547925, 0.02673975, 0.02739977]),
#  'rank_test_score': array([32, 21,  8,  1, 29, 11,  9,  5, 44, 35, 39, 42, 26, 16,  2,  6, 28,
#         23, 14,  4, 41, 34, 36, 38, 30, 18, 27,  7, 24, 20, 17, 22, 48, 46,
#         47, 45, 19, 13,  3, 15, 12, 31, 25, 10, 40, 37, 43, 33],
#        dtype=int32)}

# %%
table = pd.DataFrame.from_dict(grid_result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.346653      0.021193         0.028996        0.003217
# 1        0.673178      0.026291         0.048527        0.006072
# 2        1.005623      0.023942         0.067895        0.005509
# 3        1.516755      0.185587         0.106581        0.025396
# 4        0.350338      0.025389         0.028139        0.002100
# 5        0.705798      0.017835         0.055229        0.019693
# 6        1.068283      0.136026         0.069145        0.005439
# 7        1.489223      0.137685         0.090714        0.010832
# 8        0.497461      0.037565         0.036544        0.004286
# 9        1.103246      0.094738         0.060401        0.013101
# 10       1.329684      0.028565         0.071270        0.011646
# 11       1.659319      0.058995         0.083698        0.003428
# 12       0.350396      0.020255         0.027224        0.001443
# 13       0.659836      0.031437         0.045240        0.000642
# 14       0.996137      0.020115         0.070490        0.011034
# 15       1.383897      0.043527         0.086710        0.003189
# 16       0.343677      0.024651         0.026535        0.000627
# 17       0.652841      0.015549         0.050968        0.005215
# 18       0.992173      0.028317         0.064406        0.003983
# 19       1.322599      0.032509         0.088262        0.007772
# 20       0.428024      0.041737         0.026456        0.000598
# 21       0.916735      0.071770         0.056121        0.013177
# 22       1.272834      0.037248         0.083496        0.017259
# 23       1.647218      0.025064         0.088162        0.013291
# 24       0.800311      0.038661         0.028504        0.003107
# 25       1.571396      0.031362         0.047388        0.004865
# 26       2.342626      0.041128         0.074797        0.014840
# 27       3.078700      0.029827         0.089884        0.008417
# 28       0.777037      0.012538         0.028918        0.003626
# 29       1.568649      0.064554         0.044098        0.000332
# 30       2.336910      0.065280         0.067979        0.008968
# 31       3.147870      0.038182         0.079717        0.000985
# 32       1.252315      0.019885         0.029543        0.003961
# 33       2.589107      0.028538         0.049295        0.008698
# 34       3.789216      0.044486         0.068258        0.007596
# 35       6.173456      0.497081         0.181365        0.186129
# 36       0.469742      0.062987         0.045324        0.017859
# 37       0.835699      0.023466         0.057410        0.006389
# 38       1.365010      0.148411         0.075015        0.010477
# 39       1.716981      0.140483         0.102600        0.008695
# 40       0.570104      0.079503         0.043212        0.024233
# 41       1.148517      0.193529         0.063234        0.015526
# 42       1.610791      0.172331         0.081523        0.007025
# 43       2.270741      0.382156         0.160065        0.119721
# 44       0.757559      0.240371         0.042679        0.014249
# 45       1.545309      0.300317         0.053890        0.005092
# 46       1.565964      0.129427         0.067439        0.003099
# 47       2.090745      0.086540         0.098766        0.014111
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  50
# 1    squared_error               sqrt                 100
# 2    squared_error               sqrt                 150
# 3    squared_error               sqrt                 200
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6    squared_error               log2                 150
# 7    squared_error               log2                 200
# 8    squared_error               None                  50
# 9    squared_error               None                 100
# 10   squared_error               None                 150
# 11   squared_error               None                 200
# 12    friedman_mse               sqrt                  50
# 13    friedman_mse               sqrt                 100
# 14    friedman_mse               sqrt                 150
# 15    friedman_mse               sqrt                 200
# 16    friedman_mse               log2                  50
# 17    friedman_mse               log2                 100
# 18    friedman_mse               log2                 150
# 19    friedman_mse               log2                 200
# 20    friedman_mse               None                  50
# 21    friedman_mse               None                 100
# 22    friedman_mse               None                 150
# 23    friedman_mse               None                 200
# 24  absolute_error               sqrt                  50
# 25  absolute_error               sqrt                 100
# 26  absolute_error               sqrt                 150
# 27  absolute_error               sqrt                 200
# 28  absolute_error               log2                  50
# 29  absolute_error               log2                 100
# 30  absolute_error               log2                 150
# 31  absolute_error               log2                 200
# 32  absolute_error               None                  50
# 33  absolute_error               None                 100
# 34  absolute_error               None                 150
# 35  absolute_error               None                 200
# 36         poisson               sqrt                  50
# 37         poisson               sqrt                 100
# 38         poisson               sqrt                 150
# 39         poisson               sqrt                 200
# 40         poisson               log2                  50
# 41         poisson               log2                 100
# 42         poisson               log2                 150
# 43         poisson               log2                 200
# 44         poisson               None                  50
# 45         poisson               None                 100
# 46         poisson               None                 150
# 47         poisson               None                 200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.843879
# 1   {'criterion': 'squared_error', 'max_features':...           0.847097
# 2   {'criterion': 'squared_error', 'max_features':...           0.846966
# 3   {'criterion': 'squared_error', 'max_features':...           0.843811
# 4   {'criterion': 'squared_error', 'max_features':...           0.845079
# 5   {'criterion': 'squared_error', 'max_features':...           0.847777
# 6   {'criterion': 'squared_error', 'max_features':...           0.847396
# 7   {'criterion': 'squared_error', 'max_features':...           0.846332
# 8   {'criterion': 'squared_error', 'max_features':...           0.845316
# 9   {'criterion': 'squared_error', 'max_features':...           0.845071
# 10  {'criterion': 'squared_error', 'max_features':...           0.846507
# 11  {'criterion': 'squared_error', 'max_features':...           0.846475
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.844318
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.847150
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.845885
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.846564
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.846634
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.848971
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.848166
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.847733
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.843899
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.852092
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.851707
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.848485
# 24  {'criterion': 'absolute_error', 'max_features'...           0.840341
# 25  {'criterion': 'absolute_error', 'max_features'...           0.849298
# 26  {'criterion': 'absolute_error', 'max_features'...           0.844694
# 27  {'criterion': 'absolute_error', 'max_features'...           0.851121
# 28  {'criterion': 'absolute_error', 'max_features'...           0.849259
# 29  {'criterion': 'absolute_error', 'max_features'...           0.848347
# 30  {'criterion': 'absolute_error', 'max_features'...           0.847447
# 31  {'criterion': 'absolute_error', 'max_features'...           0.847936
# 32  {'criterion': 'absolute_error', 'max_features'...           0.842226
# 33  {'criterion': 'absolute_error', 'max_features'...           0.847117
# 34  {'criterion': 'absolute_error', 'max_features'...           0.844154
# 35  {'criterion': 'absolute_error', 'max_features'...           0.847542
# 36  {'criterion': 'poisson', 'max_features': 'sqrt...           0.852736
# 37  {'criterion': 'poisson', 'max_features': 'sqrt...           0.846118
# 38  {'criterion': 'poisson', 'max_features': 'sqrt...           0.849776
# 39  {'criterion': 'poisson', 'max_features': 'sqrt...           0.844786
# 40  {'criterion': 'poisson', 'max_features': 'log2...           0.844663
# 41  {'criterion': 'poisson', 'max_features': 'log2...           0.842358
# 42  {'criterion': 'poisson', 'max_features': 'log2...           0.844856
# 43  {'criterion': 'poisson', 'max_features': 'log2...           0.845243
# 44  {'criterion': 'poisson', 'max_features': None,...           0.848980
# 45  {'criterion': 'poisson', 'max_features': None,...           0.844466
# 46  {'criterion': 'poisson', 'max_features': None,...           0.848814
# 47  {'criterion': 'poisson', 'max_features': None,...           0.849516
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.815235           0.797809           0.826245
# 1            0.822168           0.800866           0.833975
# 2            0.825469           0.803723           0.834864
# 3            0.829719           0.804485           0.838552
# 4            0.815646           0.805019           0.836167
# 5            0.827558           0.802136           0.834807
# 6            0.822217           0.802022           0.836006
# 7            0.826173           0.803173           0.836461
# 8            0.815031           0.791309           0.808268
# 9            0.818561           0.796593           0.813067
# 10           0.819484           0.792534           0.811415
# 11           0.815407           0.793981           0.808382
# 12           0.824002           0.795404           0.838981
# 13           0.823121           0.804439           0.832688
# 14           0.824590           0.804665           0.841294
# 15           0.826586           0.802911           0.834749
# 16           0.821807           0.798026           0.834089
# 17           0.825874           0.798593           0.834331
# 18           0.822911           0.805530           0.834039
# 19           0.827025           0.803188           0.838530
# 20           0.810406           0.800479           0.812867
# 21           0.819061           0.794873           0.811503
# 22           0.815668           0.788831           0.815404
# 23           0.820067           0.791638           0.812794
# 24           0.818580           0.799404           0.833928
# 25           0.822561           0.807000           0.832176
# 26           0.821315           0.806594           0.830096
# 27           0.824740           0.805543           0.830489
# 28           0.825883           0.807561           0.822112
# 29           0.819546           0.801929           0.833648
# 30           0.823055           0.805412           0.832492
# 31           0.820069           0.806660           0.831319
# 32           0.803302           0.778926           0.809180
# 33           0.809292           0.774781           0.812023
# 34           0.813984           0.781457           0.802803
# 35           0.816451           0.784768           0.804569
# 36           0.820044           0.796089           0.842529
# 37           0.824624           0.808023           0.832891
# 38           0.828562           0.799182           0.837649
# 39           0.821028           0.802382           0.836777
# 40           0.822579           0.802031           0.838734
# 41           0.817840           0.798167           0.829214
# 42           0.823451           0.801697           0.834998
# 43           0.825271           0.803288           0.836937
# 44           0.817541           0.795534           0.809230
# 45           0.821494           0.793293           0.813157
# 46           0.818009           0.794815           0.806145
# 47           0.824441           0.795432           0.813454
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.771905         0.811015        0.024633               32
# 1            0.770705         0.814962        0.026846               21
# 2            0.771518         0.816508        0.026580                8
# 3            0.773320         0.817977        0.026096                1
# 4            0.766381         0.813658        0.027596               29
# 5            0.768739         0.816203        0.028009               11
# 6            0.774419         0.816412        0.025877                9
# 7            0.772131         0.816854        0.026561                5
# 8            0.769335         0.805852        0.025268               44
# 9            0.772712         0.809201        0.023998               35
# 10           0.769682         0.807925        0.025821               39
# 11           0.771650         0.807179        0.024697               42
# 12           0.766958         0.813933        0.028990               26
# 13           0.771409         0.815761        0.026158               16
# 14           0.771113         0.817510        0.027344                2
# 15           0.772536         0.816669        0.026291                6
# 16           0.768192         0.813750        0.027867               28
# 17           0.765377         0.814629        0.029587               23
# 18           0.769363         0.816002        0.027175               14
# 19           0.768900         0.817075        0.028330                4
# 20           0.769334         0.807397        0.023950               41
# 21           0.769144         0.809335        0.027393               34
# 22           0.770487         0.808419        0.027560               36
# 23           0.767586         0.808114        0.027234               38
# 24           0.767609         0.811972        0.026293               30
# 25           0.765112         0.815229        0.028570               18
# 26           0.766540         0.813848        0.026691               27
# 27           0.771360         0.816651        0.026906                7
# 28           0.768300         0.814623        0.026751               24
# 29           0.771721         0.815038        0.026549               20
# 30           0.767760         0.815233        0.027375               17
# 31           0.768769         0.814950        0.026772               22
# 32           0.755720         0.797871        0.029190               48
# 33           0.760544         0.800752        0.030466               46
# 34           0.757686         0.800017        0.029282               47
# 35           0.757267         0.802119        0.030290               45
# 36           0.764746         0.815229        0.031906               19
# 37           0.768662         0.816064        0.026726               13
# 38           0.771659         0.817366        0.028309                3
# 39           0.774470         0.815889        0.025281               15
# 40           0.772759         0.816153        0.026254               12
# 41           0.770546         0.811625        0.025144               31
# 42           0.767986         0.814598        0.027383               25
# 43           0.770735         0.816295        0.026794               10
# 44           0.767850         0.807827        0.026605               40
# 45           0.769376         0.808357        0.025479               37
# 46           0.767550         0.807067        0.026740               43
# 47           0.768051         0.810179        0.027400               33

# %%
grid_model.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 200}

# %%
grid_model.best_estimator_
# Out:
# RandomForestRegressor(max_features='sqrt', n_estimators=200)

# %% [markdown]
# ## Model Accuracy

# %%
"""
parameter                                                                       Accuracy
{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100} -     0.8183011956899856   (best score using grid CV)
"""

grid_model.best_score_
# Out:
# np.float64(0.8179774938774642)

# %% [markdown]
# ## save the model

# %%
# import pickle 
# pickle.dump(regressor, open("insurance_charge_finalModel_RF_regressor.sav","wb"))

# %% [markdown]
# ## predict the model

# %%
# insurance_charge_predict = pickle.load(open("insurance_charge_finalModel_RF_regressor.sav","rb"))
grid_model.predict([[ 52, 30.200, 1, 1, 0 ]])
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([10458.030279])
