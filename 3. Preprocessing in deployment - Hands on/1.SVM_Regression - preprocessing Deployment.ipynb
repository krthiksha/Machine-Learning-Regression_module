# %% [markdown]
# # Support vector machine - regression --->  PHASE 2 DEPLOYMENT
# ## PROBLEM STATEMENT:
# ### Profit prediction for startups based on the investment rate in different departments

# %% [markdown]
#  # DEPLOYMENT PHASE

# %% [markdown]
# ## pre processing requisites

# %%
# dataset 
import pandas as pd
dataset = pd.read_csv("50_Startups.csv")
# convert categorical to numerical
dataset = pd.get_dummies(dataset, drop_first=True, dtype=int)
# split input & output
independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]
dependent = dataset[['Profit']]
# split train & test set 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(independent,dependent, test_size=0.20, random_state=0)

# %% [markdown]
# ## pre - processing technique : Standardization in SVM regression

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# Only pre processing input data [x - independent] ( for this code)
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## PRE - PREPROCESSING THE INPUT DATA

# %%
# sc.transform()  -- uses calculated value of the mean, std deviation from sc.fit (which is calculated previously in the code)
preproceed_input = sc.transform([[165349.20	,136897.80	,471784.10	,0,	1]]) 
preproceed_input
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.02828029,  0.52173299,  2.18404776, -0.57735027,  1.36277029]])

# %% [markdown]
# ##  model prediction

# %%
# predict the model
import pickle
loaded_model = pickle.load(open('finalized_model_SVM_regression.sav','rb'))
loaded_model.predict(preproceed_input)    # return original data
# Out:
# array([190541.3082357])
