# %% [markdown]
# ## load the preprocessed input and output

# %%
import pickle 
sc =  pickle.load(open('input_scaler.sav','rb'))
scy =  pickle.load(open('output_scaler.sav','rb'))
sc
# Out:
# StandardScaler()

# %%
scy
# Out:
# StandardScaler()

# %% [markdown]
# ## preprocess the user input

# %%
preprocessed_input = sc.transform([[165349.20	,136897.80	,471784.10	,0,	1]]) 
preprocessed_input
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.02828029,  0.52173299,  2.18404776, -0.57735027,  1.36277029]])

# %% [markdown]
# ## load the model

# %%
model = pickle.load(open('svr_io_preproceed_model.sav','rb'))
model
# Out:
# SVR(C=3000, kernel='linear')

# %% [markdown]
# ## preprocess the output and predict using the model

# %%
model.predict(scy.inverse_transform(preprocessed_input))
# Out:
# array([186928.17461263])
